# %% [markdown]
# ## Data Visualization
# Data visualization is the graphic representation of data. It involves producing images that communicate relationships among the represented data to viewers. Visualizing data is an esstential part of data analysis and machine learning, but choosing the right type of visualization is often challenging. This guide provides an introduction to popluar data visualization techniques, by presenting sample use cases and providing code examples using Python.
#
# Types of graphs covered:
#
#  - Line graph
#  - Scatter plot
#  - Histogram and Frequency Distribution
#  - Heatmap
#  - Contour Plot
#  - Box Plot
#  - Bar Chart

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Line Chart
# A line chart displays information as a series of data points or markers, connected by a straight lines. You can customize the shape, size, color and other aesthetic elements of the markers and lines for better visual clarity.

# %%
yeild_apples = [0.895,0.91,0.919,0.926,0.929,0.931]

# %%
plt.plot(yeild_apples)

# %%
plt.plot(yeild_apples); #to remove unindented output

# %%
yeild_apples = [0.895,0.91,0.919,0.926,0.929,0.931]
years = range(2010,2016)

# %%
plt.plot(years,yeild_apples)

# %% [markdown]
# # Axis Label

# %%
plt.plot(years,yeild_apples)
plt.xlabel('years')
plt.ylabel('Yeild per hectare')
# Out:
# Text(0, 0.5, 'Yeild per hectare')

# %% [markdown]
# # plotting multiline

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
plt.plot(years,apples)
plt.plot(years,oranges)
plt.xlabel('years')
plt.ylabel('yeild per hectare');

# %% [markdown]
# # LAbeling

# %%
plt.plot(years,apples)
plt.plot(years,oranges)
plt.xlabel('years')
plt.ylabel('yeild per hectare');
#title
plt.title('crops yeild')
plt.legend(['apples','oranges']);

# %% [markdown]
# # Line Markers

# %%
plt.plot(years,apples, marker = 'o')
plt.plot(years,oranges, marker = '*')
plt.xlabel('years')
plt.ylabel('yeild per hectare');
#title
plt.title('crops yeild')
plt.legend(['apples','oranges']);

# %% [markdown]
# # Styling lines and markers
# -color or c : is set of colours of the line
#
# -linestyle or ls : choose between a solid or dashed line
# -linewidth or lw :  set the width of a line
#
# -markersize or ms : set the size of a markers
#
# -markeredgecolor or mec : srt the edge color for markers
#
# -markeredgewidth or mew : set the edge width for markers
#
# -markerfacecolor or mfc : set the fill color for markers
#
# -alpha : opacity of the plot

# %%
plt.plot(years,apples, marker = 'v',c='b',ls='-',lw=2,ms=8,mec='navy')
plt.plot(years,oranges, marker = '*',c='r',ls='-',lw=2,ms=8,mec='navy')
plt.xlabel('years')
plt.ylabel('yeild per hectare');
#title
plt.title('crops yeild')
plt.legend(['apples','oranges']);

# %% [markdown]
# the fmt provides short hand for specifing the line style, marker and line colors
# fmt= '[marker][line][color]'

# %%
plt.plot(years,apples,'s-b')
plt.plot(years,oranges,'o--g')
plt.xlabel('years')
plt.ylabel('yeild per hectare');
#title
plt.title('crops yeild')
plt.legend(['apples','oranges']);

# %% [markdown]
# Improving default styles using Seaborn

# %%
sns.set_style('whitegrid')

# %%
plt.plot(years,apples,'s-b')
plt.plot(years,oranges,'o--g')
plt.xlabel('years')
plt.ylabel('yeild per hectare');
#title
plt.title('crops yeild')
plt.legend(['apples','oranges']);

# %%
sns.set_style('darkgrid')

# %%
plt.plot(years,apples,'s-b')
plt.plot(years,oranges,'o--g')
plt.xlabel('years')
plt.ylabel('yeild per hectare');
#title
plt.title('crops yeild')
plt.legend(['apples','oranges']);

# %% [markdown]
# # Scatter Plot

# %%
flower_df = sns.load_dataset('iris')

# %%
flower_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flower_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flower_df.sepal_length,flower_df.sepal_width);

# %%
sns.scatterplot(flower_df.sepal_length,flower_df.sepal_width);
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # #Adding Hues

# %%
sns.scatterplot(flower_df.sepal_length,flower_df.sepal_width,hue=flower_df.species,s=100);
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# customizing seaborn figure

# %%
plt.figure(figsize=(12,6))
plt.title('Sepal dimension')
sns.scatterplot(flower_df.sepal_length,flower_df.sepal_width,hue=flower_df.species,s=100);
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Plotting using Pandas data frames

# %%
plt.title('sepal dimension')
sns.scatterplot('sepal_length','sepal_width',hue='species',s=100,
               data=flower_df)
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:title={'center':'sepal dimension'}, xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # Histogram
# Is the data for specific column

# %%
flower_df=sns.load_dataset('iris')

# %%
flower_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
flower_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
plt.title('dist of sepal_width')
plt.hist(flower_df.sepal_width)
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #controling the size and number of bins
# we can do it by using bins argument

# %%
import numpy as np
plt.hist(flower_df.sepal_width, bins=np.arange(2.0,4.5,0.25))
# Out:
# (array([ 4.,  7., 22., 24., 50., 18., 13.,  8.,  3.]),
#  array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25]),
#  <BarContainer object of 9 artists>)

# %%
#bins of unequal sizes
plt.hist(flower_df.sepal_width, bins=[1,3,4,4.5])
# Out:
# (array([57., 89.,  4.]),
#  array([1. , 3. , 4. , 4.5]),
#  <BarContainer object of 3 artists>)

# %% [markdown]
# # Multiple histogram

# %%
setosa_df = flower_df[flower_df.species == 'setosa']
versicolor_df = flower_df[flower_df.species == 'versicolor']
verginica_df = flower_df[flower_df.species == 'virginica']

# %%
plt.hist(setosa_df.sepal_width)
# Out:
# (array([ 1.,  0.,  1., 10.,  7., 15.,  6.,  6.,  2.,  2.]),
#  array([2.3 , 2.51, 2.72, 2.93, 3.14, 3.35, 3.56, 3.77, 3.98, 4.19, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(versicolor_df.sepal_width)
plt.hist(setosa_df.sepal_width)
plt.legend(['versicolor','setosa'])

# %%
plt.title('histogram')
plt.hist([setosa_df.sepal_width,versicolor_df.sepal_width,verginica_df.sepal_width])
plt.legend(['setosa','versicolor','verginica'])

# %%
plt.title('histogram')
plt.hist([setosa_df.sepal_width,versicolor_df.sepal_width,verginica_df.sepal_width],stacked=True)
plt.legend(['setosa','versicolor','verginica'])

# %% [markdown]
# # Bar chart

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
plt.plot(years,oranges)

# %%
plt.bar(years,oranges)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.plot(years,oranges,'o--r')
plt.bar(years,oranges)
plt.title('bar and plot')
# Out:
# Text(0.5, 1.0, 'bar and plot')

# %% [markdown]
# like histogram bars can also be stacked on top of one another. we use bottom atgument to olt.bar to achive this.

# %%
plt.bar(years,oranges)
plt.bar(years,apples,bottom=apples)
# Out:
# <BarContainer object of 12 artists>

# %%
tips_df =  sns.load_dataset('tips')

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
bill_avg=tips_df.groupby('day')[['total_bill']].mean()
bill_avg
# Out:
#       total_bill
# day
# Thur   17.682742
# Fri    17.151579
# Sat    20.441379
# Sun    21.410000

# %%
plt.bar(bill_avg.index,bill_avg.total_bill)
# Out:
# <BarContainer object of 4 artists>

# %%
sns.barplot('day','total_bill',data=tips_df);
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.barplot('day','total_bill',hue='sex',data=tips_df);
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Heatmap

# %%
df=sns.load_dataset('flights')
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
plt.plot(df.passengers)

# %%
flights_df = sns.load_dataset('flights').pivot('month','year','passengers')

# %%
flights_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.figure(figsize=(12,6))
plt.title('heatmap')
sns.heatmap(flights_df)
# Out:
# <AxesSubplot:title={'center':'heatmap'}, xlabel='year', ylabel='month'>

# %%
plt.figure(figsize=(12,6))
plt.title('heatmap')
sns.heatmap(flights_df,fmt='d',annot=True,cmap='Blues')
# Out:
# <AxesSubplot:title={'center':'heatmap'}, xlabel='year', ylabel='month'>

# %% [markdown]
# # Images
# Matplotlib can also be used to display images.

# %%
from PIL import Image

# %%
img = Image.open('img11.jpg')

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %% [markdown]
# An image loaded using PIL is simply  a 3D numpy array containing pixels intensities for the red, green and blue channels of rhe image. We xan convert the image into an array using np.array

# %%
img_array = np.array(img)

# %%
plt.imshow(img);

# %%
img_array.shape
# Out:
# (280, 397, 3)

# %%
img_array
# Out:
# array([[[ 41,  40,  54],
#         [ 43,  42,  58],
#         [ 46,  45,  61],
#         ...,
#         [ 96,  72,  46],
#         [ 96,  72,  46],
#         [ 96,  72,  46]],
#
#        [[ 37,  36,  50],
#         [ 41,  40,  54],
#         [ 45,  44,  60],
#         ...,
#         [ 95,  71,  45],
#         [ 95,  71,  45],
#         [ 95,  71,  45]],
#
#        [[ 34,  34,  44],
#         [ 39,  39,  51],
#         [ 44,  44,  56],
#         ...,
#         [ 94,  70,  44],
#         [ 94,  70,  44],
#         [ 94,  70,  44]],
#
#        ...,
#
#        [[128, 122, 106],
#         [133, 127, 111],
#         [137, 131, 115],
#         ...,
#         [171, 176, 156],
#         [168, 172, 155],
#         [160, 167, 149]],
#
#        [[133, 127, 111],
#         [138, 132, 116],
#         [140, 134, 118],
#         ...,
#         [170, 175, 155],
#         [165, 169, 152],
#         [155, 162, 144]],
#
#        [[132, 126, 110],
#         [137, 131, 115],
#         [138, 132, 116],
# ...

# %%
plt.imshow(img_array[100:200,100:200])

# %% [markdown]
# # Plotting multiple charts in a grid

# %%
fig,axes = plt.subplots(2,3)
plt.tight_layout(pad=2)

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
axes.shape
# Out:
# (2, 3)

# %%
fig,axes = plt.subplots(2,3,figsize=(12,9))
axes[0,0].plot(years,oranges,'o--r')
axes[0,0].plot(years,apples,'*-g')
axes[0,0].set_title('yeild ')
axes[0,0].legend(['apples','oranges'])
plt.tight_layout(pad=2)

axes[0,1].set_title('sepal length vs width ')
sns.scatterplot(flower_df.sepal_length,flower_df.sepal_width,hue=flower_df.species,ax=axes[0,1])

# Use the axes for plotting
axes[0,2].set_title('Distribution of Sepal Width')
axes[0,2].hist([setosa_df.sepal_width, versicolor_df.sepal_width, verginica_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True);

axes[0,2].legend(['Setosa', 'Versicolor', 'Virginica']);

# Pass the axes into seaborn
axes[1,0].set_title('Restaurant bills')
sns.barplot(x='day', y='total_bill', hue='sex', data=tips_df, ax=axes[1,0]);

# Pass the axes into seaborn
axes[1,1].set_title('Flight traffic')
sns.heatmap(flights_df, cmap='Blues', ax=axes[1,1]);

# Plot an image using the axes
axes[1,2].set_title('Data Science Meme')
axes[1,2].imshow(img)
axes[1,2].grid(False)
axes[1,2].set_xticks([])
axes[1,2].set_yticks([])

plt.tight_layout(pad=2);
# Out:
# C:\Users\Gaurav\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #Pair plots with Seaborn
#
# Seaborn also provides a helper function `sns.pairplot` to automatically plot several different charts for pairs of features within a dataframe.

# %%
sns.pairplot(flower_df,hue='species');

# %%
sns.pairplot(tips_df,hue='sex')
